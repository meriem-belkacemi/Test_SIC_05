# %% [markdown]
# ## Quiz #0502

# %% [markdown]
# ### "Human Activity Recognition"

# %% [markdown]
# #### Answer the following questions by providing Python code:
# #### Objectives:
# - Carry out the EDA.
# - Carry out the data pre-processing.
# - Optimize and test a predictive model of your choice.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn import metrics, preprocessing
warnings.filterwarnings(action='ignore')                  # Turn off the warnings.
# %matplotlib inline

# %% [markdown]
# #### Read in data:
# The explanation on the dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones).

# %%
# Go to the directory where the data file is located. 
# os.chdir(r'~~')                # Please, replace the path with your own.

# %%
df = pd.read_csv('data_human activity recognition.csv', header='infer')

# %%
df.shape
# Out:
# (19622, 160)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'user_name', 'raw_timestamp_part_1',
#        'raw_timestamp_part_2', 'cvtd_timestamp', 'new_window', 'num_window',
#        'roll_belt', 'pitch_belt', 'yaw_belt',
#        ...
#        'gyros_forearm_x', 'gyros_forearm_y', 'gyros_forearm_z',
#        'accel_forearm_x', 'accel_forearm_y', 'accel_forearm_z',
#        'magnet_forearm_x', 'magnet_forearm_y', 'magnet_forearm_z', 'classe'],
#       dtype='object', length=160)

# %% [markdown]
# 1). Carry out the EDA. Check for the missing values. HINT: The response variable is 'classe'.

# %%
classe = df.columns[df.isnull().any()].tolist() 
print ('\n     The following columns contain missing values : \n')
classe
# Out:
#      The following columns contain missing values :
# ['kurtosis_roll_belt',
#  'kurtosis_picth_belt',
#  'kurtosis_yaw_belt',
#  'skewness_roll_belt',
#  'skewness_roll_belt.1',
#  'skewness_yaw_belt',
#  'max_roll_belt',
#  'max_picth_belt',
#  'max_yaw_belt',
#  'min_roll_belt',
#  'min_pitch_belt',
#  'min_yaw_belt',
#  'amplitude_roll_belt',
#  'amplitude_pitch_belt',
#  'amplitude_yaw_belt',
#  'var_total_accel_belt',
#  'avg_roll_belt',
#  'stddev_roll_belt',
#  'var_roll_belt',
#  'avg_pitch_belt',
#  'stddev_pitch_belt',
#  'var_pitch_belt',
#  'avg_yaw_belt',
#  'stddev_yaw_belt',
#  'var_yaw_belt',
#  'var_accel_arm',
#  'avg_roll_arm',
#  'stddev_roll_arm',
#  'var_roll_arm',
#  'avg_pitch_arm',
#  'stddev_pitch_arm',
#  'var_pitch_arm',
#  'avg_yaw_arm',
#  'stddev_yaw_arm',
#  'var_yaw_arm',
#  'kurtosis_roll_arm',
#  'kurtosis_picth_arm',
#  'kurtosis_yaw_arm',
#  'skewness_roll_arm',
#  'skewness_pitch_arm',
#  'skewness_yaw_arm',
#  'max_roll_arm',
#  'max_picth_arm',
#  'max_yaw_arm',
#  'min_roll_arm',
#  'min_pitch_arm',
#  'min_yaw_arm',
#  'amplitude_roll_arm',
#  'amplitude_pitch_arm',
#  'amplitude_yaw_arm',
#  'kurtosis_roll_dumbbell',
#  'kurtosis_picth_dumbbell',
#  'kurtosis_yaw_dumbbell',
#  'skewness_roll_dumbbell',
#  'skewness_pitch_dumbbell',
#  'skewness_yaw_dumbbell',
#  'max_roll_dumbbell',
#  'max_picth_dumbbell',
#  'max_yaw_dumbbell',
#  'min_roll_dumbbell',
#  'min_pitch_dumbbell',
#  'min_yaw_dumbbell',
#  'amplitude_roll_dumbbell',
#  'amplitude_pitch_dumbbell',
#  'amplitude_yaw_dumbbell',
#  'var_accel_dumbbell',
#  'avg_roll_dumbbell',
#  'stddev_roll_dumbbell',
#  'var_roll_dumbbell',
#  'avg_pitch_dumbbell',
#  'stddev_pitch_dumbbell',
#  'var_pitch_dumbbell',
#  'avg_yaw_dumbbell',
#  'stddev_yaw_dumbbell',
#  'var_yaw_dumbbell',
#  'kurtosis_roll_forearm',
#  'kurtosis_picth_forearm',
#  'kurtosis_yaw_forearm',
#  'skewness_roll_forearm',
#  'skewness_pitch_forearm',
#  'skewness_yaw_forearm',
#  'max_roll_forearm',
#  'max_picth_forearm',
#  'max_yaw_forearm',
#  'min_roll_forearm',
#  'min_pitch_forearm',
#  'min_yaw_forearm',
#  'amplitude_roll_forearm',
#  'amplitude_pitch_forearm',
#  'amplitude_yaw_forearm',
#  'var_accel_forearm',
#  'avg_roll_forearm',
#  'stddev_roll_forearm',
#  'var_roll_forearm',
#  'avg_pitch_forearm',
#  'stddev_pitch_forearm',
#  'var_pitch_forearm',
#  'avg_yaw_forearm',
#  'stddev_yaw_forearm',
#  'var_yaw_forearm']

# %% [markdown]
# 2). Get rid of the columns that have more than 97% missing values.

# %%
l = rmissingvaluecol(df, 97)
new_df = df[l]
# Out:
# # Columns having more than 97 percent missing values:  100
# Columns:
#  ['amplitude_roll_dumbbell', 'var_yaw_arm', 'stddev_pitch_arm', 'stddev_yaw_arm', 'kurtosis_roll_dumbbell', 'kurtosis_roll_arm', 'var_yaw_forearm', 'max_picth_arm', 'skewness_yaw_dumbbell', 'var_roll_forearm', 'skewness_roll_forearm', 'avg_roll_forearm', 'kurtosis_picth_belt', 'min_roll_belt', 'stddev_roll_forearm', 'var_yaw_belt', 'max_yaw_dumbbell', 'stddev_roll_dumbbell', 'var_pitch_arm', 'skewness_pitch_arm', 'var_accel_arm', 'kurtosis_yaw_forearm', 'amplitude_roll_belt', 'max_yaw_belt', 'max_picth_forearm', 'max_roll_arm', 'amplitude_yaw_forearm', 'min_roll_forearm', 'avg_pitch_belt', 'skewness_yaw_belt', 'amplitude_pitch_belt', 'min_yaw_arm', 'avg_roll_belt', 'avg_yaw_dumbbell', 'kurtosis_roll_belt', 'max_roll_belt', 'stddev_yaw_forearm', 'amplitude_pitch_forearm', 'amplitude_pitch_arm', 'min_pitch_forearm', 'stddev_yaw_belt', 'max_yaw_arm', 'max_roll_dumbbell', 'avg_yaw_forearm', 'amplitude_pitch_dumbbell', 'stddev_roll_arm', 'kurtosis_yaw_belt', 'amplitude_yaw_dumbbell', 'max_roll_forearm', 'max_yaw_forearm', 'avg_yaw_belt', 'var_total_accel_belt', 'avg_yaw_arm', 'min_pitch_belt', 'stddev_pitch_belt', 'var_roll_belt', 'skewness_yaw_arm', 'var_pitch_forearm', 'max_picth_belt', 'skewness_roll_belt', 'min_yaw_belt', 'min_roll_dumbbell', 'var_pitch_dumbbell', 'var_accel_forearm', 'amplitude_yaw_belt', 'avg_roll_arm', 'min_roll_arm', 'kurtosis_yaw_arm', 'stddev_pitch_forearm', 'var_roll_arm', 'skewness_pitch_dumbbell', 'skewness_roll_belt.1', 'min_pitch_arm', 'kurtosis_picth_dumbbell', 'amplitude_yaw_arm', 'kurtosis_picth_forearm', 'min_yaw_dumbbell', 'min_yaw_forearm', 'kurtosis_yaw_dumbbell', 'skewness_roll_arm', 'var_yaw_dumbbell', 'avg_pitch_dumbbell', 'avg_roll_dumbbell', 'var_roll_dumbbell', 'stddev_roll_belt', 'amplitude_roll_arm', 'avg_pitch_arm', 'stddev_yaw_dumbbell', 'skewness_pitch_forearm', 'skewness_yaw_forearm', 'stddev_pitch_dumbbell', 'var_accel_dumbbell', 'skewness_roll_dumbbell', 'min_pitch_dumbbell', 'avg_pitch_forearm', 'kurtosis_picth_arm', 'var_pitch_belt', 'amplitude_roll_forearm', 'max_picth_dumbbell', 'kurtosis_roll_forearm']

# %% [markdown]
# 3). Get rid of the unnecessary columns. HINT: Those columns with "time" in the name and those that are obviously unnecessary.

# %%
       # <Your code goes in here>
colNames =df.columns[df.columns.str.contains(pat = 'time')].tolist()
colNames
# Out:
# ['raw_timestamp_part_1', 'raw_timestamp_part_2', 'cvtd_timestamp']

# %%
for i in colNames :
    new_df.drop(columns={i},inplace=True)
new_df = new_df.drop(['Unnamed: 0' , 'user_name'] , axis=1)

# %% [markdown]
# 4). Label encode the responde variable. HINT: use preprocessing.LabelEncoder().

# %%
encoder = preprocessing.LabelEncoder()
new_df['new_window'] = encoder.fit_transform(new_df['new_window'])
encoder = preprocessing.LabelEncoder()
new_df['classe'] = encoder.fit_transform(new_df['classe'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19622 entries, 0 to 19621
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   new_window            19622 non-null  int64
#  1   num_window            19622 non-null  int64
#  2   roll_belt             19622 non-null  float64
#  3   pitch_belt            19622 non-null  float64
#  4   yaw_belt              19622 non-null  float64
#  5   total_accel_belt      19622 non-null  int64
#  6   gyros_belt_x          19622 non-null  float64
#  7   gyros_belt_y          19622 non-null  float64
#  8   gyros_belt_z          19622 non-null  float64
#  9   accel_belt_x          19622 non-null  int64
#  10  accel_belt_y          19622 non-null  int64
#  11  accel_belt_z          19622 non-null  int64
#  12  magnet_belt_x         19622 non-null  int64
#  13  magnet_belt_y         19622 non-null  int64
#  14  magnet_belt_z         19622 non-null  int64
#  15  roll_arm              19622 non-null  float64
#  16  pitch_arm             19622 non-null  float64
#  17  yaw_arm               19622 non-null  float64
#  18  total_accel_arm       19622 non-null  int64
#  19  gyros_arm_x           19622 non-null  float64
#  20  gyros_arm_y           19622 non-null  float64
#  21  gyros_arm_z           19622 non-null  float64
#  22  accel_arm_x           19622 non-null  int64
#  23  accel_arm_y           19622 non-null  int64
#  24  accel_arm_z           19622 non-null  int64
#  25  magnet_arm_x          19622 non-null  int64
#  26  magnet_arm_y          19622 non-null  int64
#  27  magnet_arm_z          19622 non-null  int64
#  28  roll_dumbbell         19622 non-null  float64
#  29  pitch_dumbbell        19622 non-null  float64
#  30  yaw_dumbbell          19622 non-null  float64
#  31  total_accel_dumbbell  19622 non-null  int64
#  32  gyros_dumbbell_x      19622 non-null  float64
#  33  gyros_dumbbell_y      19622 non-null  float64
#  34  gyros_dumbbell_z      19622 non-null  float64
#  35  accel_dumbbell_x      19622 non-null  int64
#  36  accel_dumbbell_y      19622 non-null  int64
#  37  accel_dumbbell_z      19622 non-null  int64
#  38  magnet_dumbbell_x     19622 non-null  int64
#  39  magnet_dumbbell_y     19622 non-null  int64
#  40  magnet_dumbbell_z     19622 non-null  float64
#  41  roll_forearm          19622 non-null  float64
#  42  pitch_forearm         19622 non-null  float64
#  43  yaw_forearm           19622 non-null  float64
#  44  total_accel_forearm   19622 non-null  int64
#  45  gyros_forearm_x       19622 non-null  float64
#  46  gyros_forearm_y       19622 non-null  float64
#  47  gyros_forearm_z       19622 non-null  float64
#  48  accel_forearm_x       19622 non-null  int64
#  49  accel_forearm_y       19622 non-null  int64
#  50  accel_forearm_z       19622 non-null  int64
#  51  magnet_forearm_x      19622 non-null  int64
#  52  magnet_forearm_y      19622 non-null  float64
#  53  magnet_forearm_z      19622 non-null  float64
#  54  classe                19622 non-null  int32
# dtypes: float64(27), int32(1), int64(27)
# memory usage: 8.2 MB

# %% [markdown]
# 5). Carry out min-max scaling of the exploratory variables. HINT: use preprocessing.MinMaxScaler().

# %%
Y = new_df['classe']
new_df = new_df.drop('classe' , axis=1)

# %%
scaler = preprocessing.MinMaxScaler()
df_scaled = scaler.fit_transform(new_df)

# %%
pd.DataFrame(df_scaled)
# Out:
#         0         1         2         3         4         5         6   \
# 0      0.0  0.011587  0.158774  0.550129  0.238440  0.103448  0.319018
# 1      0.0  0.011587  0.158774  0.550129  0.238440  0.103448  0.325153
# 2      0.0  0.011587  0.158827  0.550129  0.238440  0.103448  0.319018
# 3      0.0  0.012746  0.159141  0.549957  0.238440  0.103448  0.325153
# 4      0.0  0.012746  0.159141  0.550129  0.238440  0.103448  0.325153
# ...    ...       ...       ...       ...       ...       ...       ...
# 19617  0.0  1.000000  0.921425  0.180879  0.860724  0.724138  0.432515
# 19618  0.0  1.000000  0.910948  0.176572  0.863510  0.655172  0.438650
# 19619  0.0  1.000000  0.910948  0.174849  0.863510  0.655172  0.432515
# 19620  0.0  1.000000  0.900471  0.171404  0.866295  0.620690  0.432515
# 19621  1.0  1.000000  0.900471  0.170543  0.869081  0.620690  0.426380
#
#              7         8         9   ...        44        45        46  \
# 0      0.500000  0.467532  0.482927  ...  0.333333  0.848286  0.022074
# 1      0.500000  0.467532  0.478049  ...  0.333333  0.847901  0.022074
# 2      0.500000  0.467532  0.487805  ...  0.333333  0.848286  0.022011
# 3      0.500000  0.464286  0.478049  ...  0.333333  0.847901  0.022011
# 4      0.515625  0.467532  0.482927  ...  0.333333  0.847901  0.022074
# ...         ...       ...       ...  ...       ...       ...       ...
# 19617  0.484375  0.256494  0.829268  ...  0.268519  0.913747  0.016571
# 19618  0.484375  0.256494  0.814634  ...  0.268519  0.908356  0.017798
# 19619  0.500000  0.266234  0.814634  ...  0.268519  0.906430  0.018301
# 19620  0.484375  0.282468  0.809756  ...  0.296296  0.904120  0.019244
# 19621  0.484375  0.288961  0.790244  ...  0.305556  0.900270  0.020062
#
#              47        48        49        50        51        52        53
# 0      0.033753  0.707692  0.536977  0.313433  0.647029  0.652357  0.702375
# 1      0.033753  0.707692  0.536977  0.312076  0.646516  0.655303  0.700921
# 2      0.033837  0.711795  0.537621  0.316147  0.646516  0.654040  0.698982
# 3      0.033837  0.704615  0.538907  0.314790  0.647541  0.654040  0.698982
# 4      0.033753  0.704615  0.538907  0.314790  0.647029  0.652778  0.700921
# ...         ...       ...       ...       ...       ...       ...       ...
# 19617  0.032791  0.232821  0.362701  0.554953  0.550717  0.130051  0.474552
# 19618  0.033837  0.232821  0.347910  0.546811  0.578381  0.109848  0.454193
# 19619  0.034046  0.241026  0.342765  0.544098  0.596311  0.101852  0.437712
# 19620  0.034046  0.233846  0.315756  0.535957  0.620902  0.091751  0.424140
# 19621  0.034171  0.225641  0.304180  0.534600  0.625000  0.088384  0.418323
#
# [19622 rows x 54 columns]

# %% [markdown]
# 6). Choose an algorithm and carry out the predictive analysis.
#
# - Optimize the hyperparameter(s)
# - Calculate the accuracy.
# - Aim for upper 90% accuracy.

# %%
x_train, x_test, y_train, y_test = train_test_split(   df_scaled, Y, test_size=0.33, random_state=42)

# %%
knn = KNeighborsClassifier()
rf = RandomForestClassifier()
adb = AdaBoostClassifier()
gb = GradientBoostingClassifier()
xgb = XGBClassifier()

# %%
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
print("RandomForest Accuracy : ",metrics.accuracy_score(y_test,y_pred))
# Out:
# RandomForest Accuracy :  0.9981470043236566

# %%
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
print("KNN Accuracy : ",metrics.accuracy_score(y_test,y_pred))
# Out:
# KNN Accuracy :  0.9478072884496603

# %%
adb.fit(x_train,y_train)
y_pred = adb.predict(x_test)
print("AdaBoost Accuracy : ",metrics.accuracy_score(y_test,y_pred))
# Out:
# AdaBoost Accuracy :  0.7251389746757257

# %%
gb.fit(x_train,y_train)
y_pred = gb.predict(x_test)
print("GradientBoosting Accuracy : ",metrics.accuracy_score(y_test,y_pred))
# Out:
# GradientBoosting Accuracy :  0.9908894379246448

# %%
xgb.fit(x_train,y_train)
y_pred = xgb.predict(x_test)
print("XGB Accuracy : ",metrics.accuracy_score(y_test,y_pred))
# Out:
# [10:20:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB Accuracy :  0.9995367510809141

# %% [markdown]
# We can notice that Random Forest, XGB and Gradient Boosting give the best accuracies, and these ones are pretty good !
